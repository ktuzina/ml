# %%
import os
try:
  import wget
except:
  # !pip install wget
  import wget
import tarfile


out_dir = 'data/svhn'

train_32_32 = ('http://ufldl.stanford.edu/housenumbers/train_32x32.mat', 'train_32x32.mat')
test_32_32 = ('http://ufldl.stanford.edu/housenumbers/test_32x32.mat', 'test_32x32.mat')
extra_32_32 = ('http://ufldl.stanford.edu/housenumbers/extra_32x32.mat', 'extra_32x32.mat')

train_large = ('http://ufldl.stanford.edu/housenumbers/train.tar.gz', 'train.tar.gz')
test_large = ('http://ufldl.stanford.edu/housenumbers/test.tar.gz', 'test.tar.gz')
extra_large = ('http://ufldl.stanford.edu/housenumbers/extra.tar.gz', 'extra.tar.gz')
# Out:
# Collecting wget
#   Downloading https://files.pythonhosted.org/packages/47/6a/62e288da7bcda82b935ff0c6cfe542970f04e29c756b0e147251b2fb251f/wget-3.2.zip
# Building wheels for collected packages: wget
#   Building wheel for wget (setup.py) ... done
#   Created wheel for wget: filename=wget-3.2-cp36-none-any.whl size=9682 sha256=9c5ce1f99ba63d91e08bb5c50058c1edbbf7467535112679ec92b386f0a6d12c
#   Stored in directory: /root/.cache/pip/wheels/40/15/30/7d8f7cea2902b4db79e3fea550d7d7b85ecb27ef992b618f3f
# Successfully built wget
# Installing collected packages: wget
# Successfully installed wget-3.2

# %%
import tensorflow as tf
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
def download_data(url, filename, out_dir=out_dir):
    filename = os.path.join(out_dir, filename)

    if not os.path.exists(out_dir):
        os.makedirs(out_dir)

    if not os.path.exists(filename):
        print(f"Downloading {filename}.")
        wget.download(url, filename)
        print()
    else:
        print(f"Skipping {filename} download (already exists)")


def extract_data(filename, out_dir=out_dir):
    filename = os.path.join(out_dir, filename)

    print(f"Extracting {filename}")
    with tarfile.open(filename) as tar:
        tar.extractall(out_dir)

download_data(*train_32_32)
download_data(*test_32_32)
download_data(*extra_32_32)

download_data(*train_large)
download_data(*test_large)
download_data(*extra_large)

extract_data(train_large[1])
extract_data(test_large[1])
extract_data(extra_large[1])
# Out:
# Downloading data/svhn/train_32x32.mat.
#
# Downloading data/svhn/test_32x32.mat.
#
# Downloading data/svhn/extra_32x32.mat.
#
# Downloading data/svhn/train.tar.gz.
#
# Downloading data/svhn/test.tar.gz.
#
# Downloading data/svhn/extra.tar.gz.
#
# Extracting data/svhn/train.tar.gz
# Extracting data/svhn/test.tar.gz
# Extracting data/svhn/extra.tar.gz

# %%
# -*- coding: utf-8 -*-
from tensorflow import keras
import numpy as np
from PIL import Image
from pathlib import Path
from scipy import io
import h5py
import json

def to_one_hot(a, n):
    result = np.zeros(shape=(a.shape[0], n))
    result[np.arange(len(a)), a] = 1
    return result

def load_multiple_digits_data(dir='data/svhn', train=True, extra=False):

    def parse_digit_struct(file):
        print('file - ' + str(file))
        if Path(f"{file}.cache.json").exists() and os.stat(f"{file}.cache.json").st_size != 0:
            print('exist')
            with open(f"{file}.cache.json", "r") as f:
                images = json.load(f)
                print(f'Loaded cached image attrs from {file}.cache.json')
                return images

        f = h5py.File(file, 'r')
        print(f'Opened file {file}')

        names = f['digitStruct']['name']
        bbox = f['digitStruct']['bbox']

        def extract_name(i):
            return ''.join([chr(c[0]) for c in f[names[i][0]].value])

        def extract_attr(i, attr):
            attr = f[bbox[i].item()][attr]
            if len(attr) > 1:
                return [f[attr.value[j].item()].value[0][0] for j in range(len(attr))]
            else:
                return [attr.value[0][0]]

        images = {}
        print(f'Extracting image attrs from {file}: ', end='')
        for i in range(len(names)):
            name = extract_name(i)
            images[name] = {
                "label": extract_attr(i, 'label'),
                "top": extract_attr(i, 'top'),
                "left": extract_attr(i, 'left'),
                "height": extract_attr(i, 'height'),
                "width": extract_attr(i, 'width')
            }
            if i % 1000 == 0:
                print('.', end='', flush=True)
        print()

        with open(f"{file}.cache.json", 'w+') as f:
            json.dump(images, f)
        return images

    def process_images(dir):
        cache_file = Path(dir) / 'cache.npz'
        if cache_file.exists():
            f = np.load(cache_file)
            print(f'Loaded cached arrays for {dir}')
            return [v for k, v in f.items()]

        attrs = parse_digit_struct(Path(dir) / 'digitStruct.mat')

        x, y = [], []
        print(f'Processing images from {dir}: ', end='', flush=True)
        for i, name in enumerate(os.listdir(dir)):
            if name not in attrs:
                print('s', end='', flush=True)
                continue

            img = Image.open(Path(dir) / name)

            height = int(max(attrs[name]['height']))
            width = int(max(attrs[name]['width']))
            left = max(int(min(attrs[name]['left'])) - 0.5 * width, 0)
            top = max(int(min(attrs[name]['top'])) - 0.5 * height, 0)
            right = min(int(max(attrs[name]['left'])) + 1.5 * width, img.size[0])
            bottom = min(int(max(attrs[name]['top'])) + 1.5 * height, img.size[1])

            img = img.crop(box=(left, top, right, bottom))
            img = img.resize((96, 96))

            label = [d % 10 for d in attrs[name]['label']]
            if len(label) > 6:
                print('e', end='', flush=True)
                continue

            label += [10] * (6 - len(label))
            label = to_one_hot(np.array(label, dtype=np.int), 11)

            x.append(np.array(img))
            y.append(np.array(label))

            if i % 1000 == 0:
                print('.', end='', flush=True)
        print()

        x = np.array(x, dtype=np.uint8)
        y = np.array(y, dtype=np.uint8)
        np.savez(Path(dir) / "cache.npz", x, y)
        return x, y

    x_test, y_test = process_images(Path(dir) / 'test/')

    x_train, y_train = None, None
    if train:
        x_train, y_train = process_images(Path(dir) / 'train/')

    x_extra, y_extra = None, None
    if extra:
        x_extra, y_extra = process_images(Path(dir) / 'extra/')

    return (
        x_train, y_train,
        x_test, y_test,
        x_extra, y_extra
    )

    x_test, y_test = process_images(Path(dir) / 'test/')

    x_train, y_train = None, None
    if train:
        x_train, y_train = process_images(Path(dir) / 'train/')

    x_extra, y_extra = None, None
    if extra:
        x_extra, y_extra = process_images(Path(dir) / 'extra/')

    return (
        x_train, y_train,
        x_test, y_test,
        x_extra, y_extra
    )

# %%
x_train, y_train, x_test, y_test, _, _ = load_multiple_digits_data()
from sklearn.model_selection import train_test_split
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.1)

def to_y(a, n):
    return [a[:,i,:] for i in range(n)]

if y_train is not None and y_val is not None and y_test is not None:
            y_train = to_y(y_train, 6)
            y_val = to_y(y_val, 6)
            y_test = to_y(y_test, 6)
# Out:
# file - data/svhn/test/digitStruct.mat
# Opened file data/svhn/test/digitStruct.mat
# Extracting image attrs from data/svhn/test/digitStruct.mat: .
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:32: H5pyDeprecationWarning: dataset.value has been deprecated. Use dataset[()] instead.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:39: H5pyDeprecationWarning: dataset.value has been deprecated. Use dataset[()] instead.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:37: H5pyDeprecationWarning: dataset.value has been deprecated. Use dataset[()] instead.
# .............
# Processing images from data/svhn/test: ...........s.s.s.
# file - data/svhn/train/digitStruct.mat
# Opened file data/svhn/train/digitStruct.mat
# Extracting image attrs from data/svhn/train/digitStruct.mat: ..................................
# Processing images from data/svhn/train: ...........................s...s..s..

# %%
y_train[1].shape
# Out:
# (30061, 11)

# %%
import tensorflow as tf

from tensorflow import keras

input = keras.layers.Input(shape=(96, 96, 3))

x = keras.layers.Conv2D(16, 5, activation='relu', padding='same')(input)
x = keras.layers.MaxPool2D(pool_size=(2, 2), padding = 'same')(x)
x = keras.layers.Conv2D(32, 5, activation='relu', padding='same')(x)
x = keras.layers.MaxPool2D(pool_size=(2, 2), padding='same')(x)
x = keras.layers.Conv2D(64, 5, activation='relu', padding='same')(x)
x = keras.layers.MaxPool2D(pool_size=(2, 2), padding='same')(x)
x = keras.layers.Flatten()(x)
x = keras.layers.Dropout(rate=0.1)(x)
x = keras.layers.Dense(100, activation='relu')(x)
x = keras.layers.Dropout(rate=0.1)(x)

out1 = keras.layers.Dense(11,  activation='linear')(x)
out2 = keras.layers.Dense(11,  activation='linear')(x)
out3 = keras.layers.Dense(11,  activation='linear')(x)
out4 = keras.layers.Dense(11,  activation='linear')(x)
out5 = keras.layers.Dense(11,  activation='linear')(x)
out6 = keras.layers.Dense(11,  activation='linear')(x)

model = keras.models.Model(
   inputs=[input],
   outputs=[out1,out2,out3,out4,out5,out6]
)
model.compile(
   optimizer=keras.optimizers.Adam(lr=0.001),
   loss='categorical_crossentropy',
   metrics=['categorical_accuracy']#,
   #loss_weights=[1, 1, 0.5, 0.3, 0.1, 0.05]
)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 96, 96, 3)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 96, 96, 16)   1216        input_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 48, 48, 16)   0           conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 48, 48, 32)   12832       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 24, 24, 32)   0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 24, 24, 64)   51264       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 12, 12, 64)   0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 9216)         0           max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 9216)         0           flatten[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 100)          921700      dropout[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 100)          0           dense[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 11)           1111        dropout_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 11)           1111        dropout_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 11)           1111        dropout_1[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 11)           1111        dropout_1[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 11)           1111        dropout_1[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 11)           1111        dropout_1[0][0]
# ==================================================================================================
# Total params: 993,678
# Trainable params: 993,678
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model.fit(
                x_train,
                y_train,
                epochs=100,
                batch_size=32,
                verbose=2,
                validation_split=0.1,
                callbacks=[
                    keras.callbacks.EarlyStopping(
                        patience=10,
                        restore_best_weights=True
                    )
                ]
            )
# Out:
# Epoch 1/100
# 846/846 - 9s - loss: 63.4353 - dense_1_loss: 8.0610 - dense_2_loss: 8.1101 - dense_3_loss: 8.2673 - dense_4_loss: 7.9674 - dense_5_loss: 15.6339 - dense_6_loss: 15.3956 - dense_1_categorical_accuracy: 0.1286 - dense_2_categorical_accuracy: 0.0956 - dense_3_categorical_accuracy: 0.5422 - dense_4_categorical_accuracy: 0.0051 - dense_5_categorical_accuracy: 0.8513 - dense_6_categorical_accuracy: 0.1139 - val_loss: 61.1908 - val_dense_1_loss: 7.9438 - val_dense_2_loss: 6.7803 - val_dense_3_loss: 13.6837 - val_dense_4_loss: 0.5469 - val_dense_5_loss: 16.1181 - val_dense_6_loss: 16.1181 - val_dense_1_categorical_accuracy: 0.1107 - val_dense_2_categorical_accuracy: 0.0971 - val_dense_3_categorical_accuracy: 0.6864 - val_dense_4_categorical_accuracy: 0.0063 - val_dense_5_categorical_accuracy: 1.0000 - val_dense_6_categorical_accuracy: 0.0000e+00
# Epoch 2/100
# 846/846 - 9s - loss: 64.1255 - dense_1_loss: 8.8686 - dense_2_loss: 8.1161 - dense_3_loss: 9.2715 - dense_4_loss: 6.1974 - dense_5_loss: 16.0174 - dense_6_loss: 15.6545 - dense_1_categorical_accuracy: 0.0817 - dense_2_categorical_accuracy: 0.1185 - dense_3_categorical_accuracy: 0.4549 - dense_4_categorical_accuracy: 0.0048 - dense_5_categorical_accuracy: 0.5880 - dense_6_categorical_accuracy: 0.3156 - val_loss: 65.5923 - val_dense_1_loss: 11.3050 - val_dense_2_loss: 7.9168 - val_dense_3_loss: 13.7588 - val_dense_4_loss: 0.3754 - val_dense_5_loss: 16.1181 - val_dense_6_loss: 16.1181 - val_dense_1_categorical_accuracy: 0.0609 - val_dense_2_categorical_accuracy: 0.0845 - val_dense_3_categorical_accuracy: 0.0289 - val_dense_4_categorical_accuracy: 0.0063 - val_dense_5_categorical_accuracy: 1.0000 - val_dense_6_categorical_accuracy: 0.0000e+00
# Epoch 3/100
# 846/846 - 9s - loss: 66.5104 - dense_1_loss: 9.4413 - dense_2_loss: 8.2471 - dense_3_loss: 8.1853 - dense_4_loss: 8.5499 - dense_5_loss: 16.0945 - dense_6_loss: 15.9924 - dense_1_categorical_accuracy: 0.1608 - dense_2_categorical_accuracy: 0.0958 - dense_3_categorical_accuracy: 0.2654 - dense_4_categorical_accuracy: 0.0049 - dense_5_categorical_accuracy: 0.9875 - dense_6_categorical_accuracy: 0.0657 - val_loss: 79.9128 - val_dense_1_loss: 7.2900 - val_dense_2_loss: 10.8539 - val_dense_3_loss: 13.9469 - val_dense_4_loss: 15.5858 - val_dense_5_loss: 16.1181 - val_dense_6_loss: 16.1181 - val_dense_1_categorical_accuracy: 0.0030 - val_dense_2_categorical_accuracy: 0.1450 - val_dense_3_categorical_accuracy: 0.0289 - val_dense_4_categorical_accuracy: 0.0086 - val_dense_5_categorical_accuracy: 1.0000 - val_dense_6_categorical_accuracy: 1.0000
# Epoch 4/100
# 846/846 - 9s - loss: 67.7601 - dense_1_loss: 7.2615 - dense_2_loss: 8.0330 - dense_3_loss: 13.9305 - dense_4_loss: 7.5413 - dense_5_loss: 16.1095 - dense_6_loss: 14.8845 - dense_1_categorical_accuracy: 0.0120 - dense_2_categorical_accuracy: 0.1525 - dense_3_categorical_accuracy: 0.0916 - dense_4_categorical_accuracy: 0.0062 - dense_5_categorical_accuracy: 0.8296 - dense_6_categorical_accuracy: 0.9045 - val_loss: 80.0645 - val_dense_1_loss: 7.4454 - val_dense_2_loss: 10.8539 - val_dense_3_loss: 13.9469 - val_dense_4_loss: 15.5821 - val_dense_5_loss: 16.1181 - val_dense_6_loss: 16.1181 - val_dense_1_categorical_accuracy: 0.0030 - val_dense_2_categorical_accuracy: 0.1450 - val_dense_3_categorical_accuracy: 0.0289 - val_dense_4_categorical_accuracy: 0.0086 - val_dense_5_categorical_accuracy: 1.0000 - val_dense_6_categorical_accuracy: 1.0000
# Epoch 5/100
# 846/846 - 9s - loss: 63.9211 - dense_1_loss: 8.6271 - dense_2_loss: 9.0745 - dense_3_loss: 13.8548 - dense_4_loss: 1.9166 - dense_5_loss: 16.1154 - dense_6_loss: 14.3326 - dense_1_categorical_accuracy: 0.0087 - dense_2_categorical_accuracy: 0.1537 - dense_3_categorical_accuracy: 0.0944 - dense_4_categorical_accuracy: 0.0064 - dense_5_categorical_accuracy: 0.8236 - dense_6_categorical_accuracy: 0.9019 - val_loss: 66.8033 - val_dense_1_loss: 8.8281 - val_dense_2_loss: 10.8539 - val_dense_3_loss: 13.9469 - val_dense_4_loss: 0.9382 - val_dense_5_loss: 16.1181 - val_dense_6_loss: 16.1181 - val_dense_1_categorical_accuracy: 0.0030 - val_dense_2_categorical_accuracy: 0.1450 - val_dense_3_categorical_accuracy: 0.0289 - val_dense_4_categorical_accuracy: 0.0086 - val_dense_5_categorical_accuracy: 1.0000 - val_dense_6_categorical_accuracy: 1.0000
# Epoch 6/100
# 846/846 - 9s - loss: 73.6544 - dense_1_loss: 8.7543 - dense_2_loss: 8.1577 - dense_3_loss: 14.0258 - dense_4_loss: 13.0543 - dense_5_loss: 16.1028 - dense_6_loss: 13.5598 - dense_1_categorical_accuracy: 0.0091 - dense_2_categorical_accuracy: 0.1537 - dense_3_categorical_accuracy: 0.0941 - dense_4_categorical_accuracy: 0.0064 - dense_5_categorical_accuracy: 0.8290 - dense_6_categorical_accuracy: 0.9062 - val_loss: 75.8575 - val_dense_1_loss: 8.8281 - val_dense_2_loss: 5.2642 - val_dense_3_loss: 13.9469 - val_dense_4_loss: 15.5821 - val_dense_5_loss: 16.1181 - val_dense_6_loss: 16.1181 - val_dense_1_categorical_accuracy: 0.0030 - val_dense_2_categorical_accuracy: 0.1450 - val_dense_3_categorical_accuracy: 0.0289 - val_dense_4_categorical_accuracy: 0.0086 - val_dense_5_categorical_accuracy: 1.0000 - val_dense_6_categorical_accuracy: 1.0000
# Epoch 7/100
# 846/846 - 9s - loss: 67.7574 - dense_1_loss: 8.5226 - dense_2_loss: 7.7300 - dense_3_loss: 12.9595 - dense_4_loss: 7.9995 - dense_5_loss: 16.1161 - dense_6_loss: 14.4299 - dense_1_categorical_accuracy: 0.0097 - dense_2_categorical_accuracy: 0.1541 - dense_3_categorical_accuracy: 0.0925 - dense_4_categorical_accuracy: 0.0065 - dense_5_categorical_accuracy: 0.8272 - dense_6_categorical_accuracy: 0.9064 - val_loss: 81.4474 - val_dense_1_loss: 8.8281 - val_dense_2_loss: 10.8539 - val_dense_3_loss: 13.9469 - val_dense_4_loss: 15.5823 - val_dense_5_loss: 16.1181 - val_dense_6_loss: 16.1181 - val_dense_1_categorical_accuracy: 0.0030 - val_dense_2_categorical_accuracy: 0.1450 - val_dense_3_categorical_accuracy: 0.0289 - val_dense_4_categorical_accuracy: 0.0086 - val_dense_5_categorical_accuracy: 1.0000 - val_dense_6_categorical_accuracy: 1.0000
# Epoch 8/100
# 846/846 - 9s - loss: 60.2820 - dense_1_loss: 8.0704 - dense_2_loss: 9.8864 - dense_3_loss: 8.5590 - dense_4_loss: 2.7345 - dense_5_loss: 16.1014 - dense_6_loss: 14.9303 - dense_1_categorical_accuracy: 0.0072 - dense_2_categorical_accuracy: 0.1531 - dense_3_categorical_accuracy: 0.0963 - dense_4_categorical_accuracy: 0.0064 - dense_5_categorical_accuracy: 0.8252 - dense_6_categorical_accuracy: 0.9108 - val_loss: 53.0873 - val_dense_1_loss: 7.2900 - val_dense_2_loss: 10.8539 - val_dense_3_loss: 2.1712 - val_dense_4_loss: 0.5360 - val_dense_5_loss: 16.1181 - val_dense_6_loss: 16.1181 - val_dense_1_categorical_accuracy: 0.0030 - val_dense_2_categorical_accuracy: 0.1450 - val_dense_3_categorical_accuracy: 0.0289 - val_dense_4_categorical_accuracy: 0.0086 - val_dense_5_categorical_accuracy: 1.0000 - val_dense_6_categorical_accuracy: 1.0000
# Epoch 9/100
# 846/846 - 9s - loss: 55.0981 - dense_1_loss: 7.9719 - dense_2_loss: 9.9150 - dense_3_loss: 7.4757 - dense_4_loss: 1.8536 - dense_5_loss: 16.0017 - dense_6_loss: 11.8803 - dense_1_categorical_accuracy: 0.0083 - dense_2_categorical_accuracy: 0.1536 - dense_3_categorical_accuracy: 0.0921 - dense_4_categorical_accuracy: 0.0059 - dense_5_categorical_accuracy: 0.8200 - dense_6_categorical_accuracy: 0.9073 - val_loss: 48.7449 - val_dense_1_loss: 7.2900 - val_dense_2_loss: 10.8539 - val_dense_3_loss: 13.9469 - val_dense_4_loss: 0.5360 - val_dense_5_loss: 16.1181 - val_dense_6_loss: 1.1921e-07 - val_dense_1_categorical_accuracy: 0.0030 - val_dense_2_categorical_accuracy: 0.1450 - val_dense_3_categorical_accuracy: 0.0289 - val_dense_4_categorical_accuracy: 0.0086 - val_dense_5_categorical_accuracy: 1.0000 - val_dense_6_categorical_accuracy: 1.0000
# Epoch 10/100
# 846/846 - 9s - loss: 52.1825 - dense_1_loss: 7.9368 - dense_2_loss: 9.8875 - dense_3_loss: 12.8354 - dense_4_loss: 1.8570 - dense_5_loss: 16.0820 - dense_6_loss: 3.5839 - dense_1_categorical_accuracy: 0.0082 - dense_2_categorical_accuracy: 0.1535 - dense_3_categorical_accuracy: 0.0958 - dense_4_categorical_accuracy: 0.0059 - dense_5_categorical_accuracy: 0.8213 - dense_6_categorical_accuracy: 0.9053 - val_loss: 49.4474 - val_dense_1_loss: 7.2900 - val_dense_2_loss: 10.8539 - val_dense_3_loss: 13.9469 - val_dense_4_loss: 0.5360 - val_dense_5_loss: 16.1181 - val_dense_6_loss: 0.7025 - val_dense_1_categorical_accuracy: 0.0030 - val_dense_2_categorical_accuracy: 0.1450 - val_dense_3_categorical_accuracy: 0.0289 - val_dense_4_categorical_accuracy: 0.0086 - val_dense_5_categorical_accuracy: 1.0000 - val_dense_6_categorical_accuracy: 1.0000
# Epoch 11/100
# 846/846 - 9s - loss: 55.6583 - dense_1_loss: 7.9707 - dense_2_loss: 9.8565 - dense_3_loss: 12.8400 - dense_4_loss: 4.1136 - dense_5_loss: 15.9181 - dense_6_loss: 4.9593 - dense_1_categorical_accuracy: 0.0082 - dense_2_categorical_accuracy: 0.1537 - dense_3_categorical_accuracy: 0.0944 - dense_4_categorical_accuracy: 0.0063 - dense_5_categorical_accuracy: 0.8188 - dense_6_categorical_accuracy: 0.9048 - val_loss: 70.3308 - val_dense_1_loss: 7.2900 - val_dense_2_loss: 10.8539 - val_dense_3_loss: 13.9469 - val_dense_4_loss: 15.5821 - val_dense_5_loss: 16.1181 - val_dense_6_loss: 6.5399 - val_dense_1_categorical_accuracy: 0.0030 - val_dense_2_categorical_accuracy: 0.1450 - val_dense_3_categorical_accuracy: 0.0289 - val_dense_4_categorical_accuracy: 0.0086 - val_dense_5_categorical_accuracy: 1.0000 - val_dense_6_categorical_accuracy: 1.0000
# Epoch 12/100
# 846/846 - 8s - loss: 65.7714 - dense_1_loss: 7.9495 - dense_2_loss: 9.8767 - dense_3_loss: 12.3772 - dense_4_loss: 14.0752 - dense_5_loss: 15.9630 - dense_6_loss: 5.5300 - dense_1_categorical_accuracy: 0.0083 - dense_2_categorical_accuracy: 0.1535 - dense_3_categorical_accuracy: 0.0952 - dense_4_categorical_accuracy: 0.0060 - dense_5_categorical_accuracy: 0.8169 - dense_6_categorical_accuracy: 0.9019 - val_loss: 81.4471 - val_dense_1_loss: 8.8281 - val_dense_2_loss: 10.8539 - val_dense_3_loss: 13.9469 - val_dense_4_loss: 15.5821 - val_dense_5_loss: 16.1181 - val_dense_6_loss: 16.1181 - val_dense_1_categorical_accuracy: 0.0030 - val_dense_2_categorical_accuracy: 0.1450 - val_dense_3_categorical_accuracy: 0.0289 - val_dense_4_categorical_accuracy: 0.0086 - val_dense_5_categorical_accuracy: 1.0000 - val_dense_6_categorical_accuracy: 1.0000
# Epoch 13/100
# 846/846 - 9s - loss: 62.2168 - dense_1_loss: 7.9899 - dense_2_loss: 9.2770 - dense_3_loss: 13.1730 - dense_4_loss: 8.3283 - dense_5_loss: 15.3711 - dense_6_loss: 8.0774 - dense_1_categorical_accuracy: 0.0128 - dense_2_categorical_accuracy: 0.1512 - dense_3_categorical_accuracy: 0.3299 - dense_4_categorical_accuracy: 0.0064 - dense_5_categorical_accuracy: 0.8364 - dense_6_categorical_accuracy: 0.9104 - val_loss: 35.5653 - val_dense_1_loss: 7.2900 - val_dense_2_loss: 9.4500 - val_dense_3_loss: 2.1712 - val_dense_4_loss: 0.5360 - val_dense_5_loss: 16.1181 - val_dense_6_loss: 1.1921e-07 - val_dense_1_categorical_accuracy: 0.0030 - val_dense_2_categorical_accuracy: 0.1450 - val_dense_3_categorical_accuracy: 0.6864 - val_dense_4_categorical_accuracy: 0.0086 - val_dense_5_categorical_accuracy: 1.0000 - val_dense_6_categorical_accuracy: 1.0000
# Epoch 14/100
# 846/846 - 9s - loss: 48.5918 - dense_1_loss: 7.6522 - dense_2_loss: 8.8044 - dense_3_loss: 12.9616 - dense_4_loss: 1.3897 - dense_5_loss: 16.0230 - dense_6_loss: 1.7607 - dense_1_categorical_accuracy: 0.0117 - dense_2_categorical_accuracy: 0.1501 - dense_3_categorical_accuracy: 0.5780 - dense_4_categorical_accuracy: 0.0064 - dense_5_categorical_accuracy: 0.9000 - dense_6_categorical_accuracy: 0.9079 - val_loss: 47.3410 - val_dense_1_loss: 7.2900 - val_dense_2_loss: 9.4500 - val_dense_3_loss: 13.9469 - val_dense_4_loss: 0.5360 - val_dense_5_loss: 16.1181 - val_dense_6_loss: 1.1921e-07 - val_dense_1_categorical_accuracy: 0.0030 - val_dense_2_categorical_accuracy: 0.1450 - val_dense_3_categorical_accuracy: 0.6864 - val_dense_4_categorical_accuracy: 0.0086 - val_dense_5_categorical_accuracy: 1.0000 - val_dense_6_categorical_accuracy: 1.0000
# Epoch 15/100
# 846/846 - 8s - loss: 50.0155 - dense_1_loss: 7.6016 - dense_2_loss: 8.8451 - dense_3_loss: 13.9561 - dense_4_loss: 0.5104 - dense_5_loss: 16.1164 - dense_6_loss: 2.9858 - dense_1_categorical_accuracy: 0.0100 - dense_2_categorical_accuracy: 0.1487 - dense_3_categorical_accuracy: 0.5791 - dense_4_categorical_accuracy: 0.0064 - dense_5_categorical_accuracy: 0.8979 - dense_6_categorical_accuracy: 0.9138 - val_loss: 63.4591 - val_dense_1_loss: 7.2900 - val_dense_2_loss: 9.4500 - val_dense_3_loss: 13.9469 - val_dense_4_loss: 0.5360 - val_dense_5_loss: 16.1181 - val_dense_6_loss: 16.1181 - val_dense_1_categorical_accuracy: 0.0030 - val_dense_2_categorical_accuracy: 0.1450 - val_dense_3_categorical_accuracy: 0.6864 - val_dense_4_categorical_accuracy: 0.0086 - val_dense_5_categorical_accuracy: 1.0000 - val_dense_6_categorical_accuracy: 1.0000
# Epoch 16/100
# 846/846 - 9s - loss: 61.1015 - dense_1_loss: 7.3682 - dense_2_loss: 8.8355 - dense_3_loss: 13.9290 - dense_4_loss: 0.4901 - dense_5_loss: 15.4764 - dense_6_loss: 15.0023 - dense_1_categorical_accuracy: 0.0096 - dense_2_categorical_accuracy: 0.1481 - dense_3_categorical_accuracy: 0.5981 - dense_4_categorical_accuracy: 0.0065 - dense_5_categorical_accuracy: 0.9022 - dense_6_categorical_accuracy: 0.9903 - val_loss: 63.4591 - val_dense_1_loss: 7.2900 - val_dense_2_loss: 9.4500 - val_dense_3_loss: 13.9469 - val_dense_4_loss: 0.5360 - val_dense_5_loss: 16.1181 - val_dense_6_loss: 16.1181 - val_dense_1_categorical_accuracy: 0.0030 - val_dense_2_categorical_accuracy: 0.1450 - val_dense_3_categorical_accuracy: 0.6864 - val_dense_4_categorical_accuracy: 0.0086 - val_dense_5_categorical_accuracy: 1.0000 - val_dense_6_categorical_accuracy: 1.0000
# Epoch 17/100
# 846/846 - 8s - loss: 59.8627 - dense_1_loss: 7.3464 - dense_2_loss: 8.8227 - dense_3_loss: 13.9496 - dense_4_loss: 0.4960 - dense_5_loss: 14.7565 - dense_6_loss: 14.4915 - dense_1_categorical_accuracy: 0.0091 - dense_2_categorical_accuracy: 0.1478 - dense_3_categorical_accuracy: 0.5787 - dense_4_categorical_accuracy: 0.0064 - dense_5_categorical_accuracy: 0.9029 - dense_6_categorical_accuracy: 0.9907 - val_loss: 63.4591 - val_dense_1_loss: 7.2900 - val_dense_2_loss: 9.4500 - val_dense_3_loss: 13.9469 - val_dense_4_loss: 0.5360 - val_dense_5_loss: 16.1181 - val_dense_6_loss: 16.1181 - val_dense_1_categorical_accuracy: 0.0030 - val_dense_2_categorical_accuracy: 0.1450 - val_dense_3_categorical_accuracy: 0.6864 - val_dense_4_categorical_accuracy: 0.0086 - val_dense_5_categorical_accuracy: 1.0000 - val_dense_6_categorical_accuracy: 1.0000
# Epoch 18/100
# 846/846 - 8s - loss: 49.9773 - dense_1_loss: 7.4949 - dense_2_loss: 8.8116 - dense_3_loss: 13.9177 - dense_4_loss: 0.5080 - dense_5_loss: 4.7466 - dense_6_loss: 14.4985 - dense_1_categorical_accuracy: 0.0099 - dense_2_categorical_accuracy: 0.1498 - dense_3_categorical_accuracy: 0.5741 - dense_4_categorical_accuracy: 0.0065 - dense_5_categorical_accuracy: 0.9000 - dense_6_categorical_accuracy: 0.9911 - val_loss: 47.3410 - val_dense_1_loss: 7.2900 - val_dense_2_loss: 9.4500 - val_dense_3_loss: 13.9469 - val_dense_4_loss: 0.5360 - val_dense_5_loss: 1.1921e-07 - val_dense_6_loss: 16.1181 - val_dense_1_categorical_accuracy: 0.0030 - val_dense_2_categorical_accuracy: 0.1450 - val_dense_3_categorical_accuracy: 0.6864 - val_dense_4_categorical_accuracy: 0.0086 - val_dense_5_categorical_accuracy: 1.0000 - val_dense_6_categorical_accuracy: 1.0000
# Epoch 19/100
# 846/846 - 8s - loss: 48.3527 - dense_1_loss: 7.5321 - dense_2_loss: 8.8112 - dense_3_loss: 13.9234 - dense_4_loss: 0.5044 - dense_5_loss: 3.0016 - dense_6_loss: 14.5799 - dense_1_categorical_accuracy: 0.0107 - dense_2_categorical_accuracy: 0.1487 - dense_3_categorical_accuracy: 0.5768 - dense_4_categorical_accuracy: 0.0064 - dense_5_categorical_accuracy: 0.8983 - dense_6_categorical_accuracy: 0.9911 - val_loss: 47.3410 - val_dense_1_loss: 7.2900 - val_dense_2_loss: 9.4500 - val_dense_3_loss: 13.9469 - val_dense_4_loss: 0.5360 - val_dense_5_loss: 1.1921e-07 - val_dense_6_loss: 16.1181 - val_dense_1_categorical_accuracy: 0.0030 - val_dense_2_categorical_accuracy: 0.1450 - val_dense_3_categorical_accuracy: 0.6864 - val_dense_4_categorical_accuracy: 0.0086 - val_dense_5_categorical_accuracy: 1.0000 - val_dense_6_categorical_accuracy: 1.0000
# Epoch 20/100
# 846/846 - 9s - loss: 56.2147 - dense_1_loss: 7.3803 - dense_2_loss: 8.8204 - dense_3_loss: 13.9075 - dense_4_loss: 0.5085 - dense_5_loss: 11.1257 - dense_6_loss: 14.4723 - dense_1_categorical_accuracy: 0.0091 - dense_2_categorical_accuracy: 0.1489 - dense_3_categorical_accuracy: 0.5783 - dense_4_categorical_accuracy: 0.0062 - dense_5_categorical_accuracy: 0.9001 - dense_6_categorical_accuracy: 0.9903 - val_loss: 63.4591 - val_dense_1_loss: 7.2900 - val_dense_2_loss: 9.4500 - val_dense_3_loss: 13.9469 - val_dense_4_loss: 0.5360 - val_dense_5_loss: 16.1181 - val_dense_6_loss: 16.1181 - val_dense_1_categorical_accuracy: 0.0030 - val_dense_2_categorical_accuracy: 0.1450 - val_dense_3_categorical_accuracy: 0.6864 - val_dense_4_categorical_accuracy: 0.0086 - val_dense_5_categorical_accuracy: 1.0000 - val_dense_6_categorical_accuracy: 1.0000
# Epoch 21/100
# 846/846 - 8s - loss: 59.5312 - dense_1_loss: 7.3137 - dense_2_loss: 8.8336 - dense_3_loss: 13.9321 - dense_4_loss: 0.5037 - dense_5_loss: 14.4731 - dense_6_loss: 14.4749 - dense_1_categorical_accuracy: 0.0096 - dense_2_categorical_accuracy: 0.1492 - dense_3_categorical_accuracy: 0.5782 - dense_4_categorical_accuracy: 0.0063 - dense_5_categorical_accuracy: 0.9004 - dense_6_categorical_accuracy: 0.9905 - val_loss: 63.4591 - val_dense_1_loss: 7.2900 - val_dense_2_loss: 9.4500 - val_dense_3_loss: 13.9469 - val_dense_4_loss: 0.5360 - val_dense_5_loss: 16.1181 - val_dense_6_loss: 16.1181 - val_dense_1_categorical_accuracy: 0.0030 - val_dense_2_categorical_accuracy: 0.1450 - val_dense_3_categorical_accuracy: 0.6864 - val_dense_4_categorical_accuracy: 0.0086 - val_dense_5_categorical_accuracy: 1.0000 - val_dense_6_categorical_accuracy: 1.0000
# Epoch 22/100
# 846/846 - 8s - loss: 59.7790 - dense_1_loss: 7.3463 - dense_2_loss: 8.8221 - dense_3_loss: 13.9335 - dense_4_loss: 0.5009 - dense_5_loss: 14.5872 - dense_6_loss: 14.5890 - dense_1_categorical_accuracy: 0.0081 - dense_2_categorical_accuracy: 0.1487 - dense_3_categorical_accuracy: 0.5807 - dense_4_categorical_accuracy: 0.0064 - dense_5_categorical_accuracy: 0.8980 - dense_6_categorical_accuracy: 0.9919 - val_loss: 63.4591 - val_dense_1_loss: 7.2900 - val_dense_2_loss: 9.4500 - val_dense_3_loss: 13.9469 - val_dense_4_loss: 0.5360 - val_dense_5_loss: 16.1181 - val_dense_6_loss: 16.1181 - val_dense_1_categorical_accuracy: 0.0030 - val_dense_2_categorical_accuracy: 0.1450 - val_dense_3_categorical_accuracy: 0.6864 - val_dense_4_categorical_accuracy: 0.0086 - val_dense_5_categorical_accuracy: 1.0000 - val_dense_6_categorical_accuracy: 1.0000
# Epoch 23/100
# 846/846 - 8s - loss: 59.6066 - dense_1_loss: 7.3172 - dense_2_loss: 8.8414 - dense_3_loss: 13.9253 - dense_4_loss: 0.5001 - dense_5_loss: 14.5104 - dense_6_loss: 14.5122 - dense_1_categorical_accuracy: 0.0093 - dense_2_categorical_accuracy: 0.1472 - dense_3_categorical_accuracy: 0.5767 - dense_4_categorical_accuracy: 0.0064 - dense_5_categorical_accuracy: 0.8984 - dense_6_categorical_accuracy: 0.9906 - val_loss: 63.4591 - val_dense_1_loss: 7.2900 - val_dense_2_loss: 9.4500 - val_dense_3_loss: 13.9469 - val_dense_4_loss: 0.5360 - val_dense_5_loss: 16.1181 - val_dense_6_loss: 16.1181 - val_dense_1_categorical_accuracy: 0.0030 - val_dense_2_categorical_accuracy: 0.1450 - val_dense_3_categorical_accuracy: 0.6864 - val_dense_4_categorical_accuracy: 0.0086 - val_dense_5_categorical_accuracy: 1.0000 - val_dense_6_categorical_accuracy: 1.0000

# %%
y_pred = model.predict(x_test)

total = np.array([True] * len(x_test))
for i, (y1, y2) in enumerate(zip(y_test, y_pred)):
  cur = np.argmax(y1, axis=1) == np.argmax(y2, axis=1)
  total = np.logical_and(total, cur)

  acc = np.mean(cur.astype(np.int))
  #history[f'test_out_{i}_acc'] = acc
  print(f'Accuracy of out_{i} = {acc:.5f}')

acc = np.mean(total.astype(np.int))
#history['test_acc'] = acc
print(f'Accuracy = {acc:.5f}')
# Out:
# Accuracy of out_0 = 0.00145
# Accuracy of out_1 = 0.19001
# Accuracy of out_2 = 0.82943
# Accuracy of out_3 = 0.00222
# Accuracy of out_4 = 0.99985
# Accuracy of out_5 = 1.00000
# Accuracy = 0.00000

# %%
# !ls data/svhn/
# Out:
# extra		 extra.tar.gz  test_32x32.mat  train		train.tar.gz
# extra_32x32.mat  test	       test.tar.gz     train_32x32.mat

# %%
_, _, x_test, y_test, x_train, y_train = load_multiple_digits_data(extra=True, train=False)
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.1)
if y_train is not None and y_val is not None and y_test is not None:
            y_train = to_y(y_train, 6)
            y_val = to_y(y_val, 6)
            y_test = to_y(y_test, 6)
# Out:
# Loaded cached arrays for data/svhn/test
# file - data/svhn/extra/digitStruct.mat
# Opened file data/svhn/extra/digitStruct.mat
# Extracting image attrs from data/svhn/extra/digitStruct.mat: .
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:32: H5pyDeprecationWarning: dataset.value has been deprecated. Use dataset[()] instead.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:37: H5pyDeprecationWarning: dataset.value has been deprecated. Use dataset[()] instead.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:39: H5pyDeprecationWarning: dataset.value has been deprecated. Use dataset[()] instead.
# ..........................................................................................................................................................................................................
# Processing images from data/svhn/extra: .................................................................................................................................................................s..................s...............s.........

# %%
model.fit(
                x_train,
                y_train,
                epochs=100,
                batch_size=32,
                verbose=2,
                validation_split=0.1,
                callbacks=[
                    keras.callbacks.EarlyStopping(
                        patience=10,
                        restore_best_weights=True
                    )
                ]
            )
# Out:
# Epoch 1/100
# 5123/5123 - 51s - loss: 60.4374 - dense_1_loss: 8.1377 - dense_2_loss: 8.4863 - dense_3_loss: 7.6266 - dense_4_loss: 4.4006 - dense_5_loss: 15.8552 - dense_6_loss: 15.9293 - dense_1_categorical_accuracy: 0.0785 - dense_2_categorical_accuracy: 0.1058 - dense_3_categorical_accuracy: 0.0663 - dense_4_categorical_accuracy: 0.0066 - dense_5_categorical_accuracy: 0.4659 - dense_6_categorical_accuracy: 0.9619 - val_loss: 58.9354 - val_dense_1_loss: 9.3872 - val_dense_2_loss: 9.2767 - val_dense_3_loss: 6.7380 - val_dense_4_loss: 1.3034 - val_dense_5_loss: 16.1120 - val_dense_6_loss: 16.1181 - val_dense_1_categorical_accuracy: 0.0639 - val_dense_2_categorical_accuracy: 0.1020 - val_dense_3_categorical_accuracy: 0.0512 - val_dense_4_categorical_accuracy: 0.0057 - val_dense_5_categorical_accuracy: 0.0000e+00 - val_dense_6_categorical_accuracy: 1.0000
# Epoch 2/100
# 5123/5123 - 51s - loss: 59.4880 - dense_1_loss: 8.4343 - dense_2_loss: 8.6262 - dense_3_loss: 8.2436 - dense_4_loss: 2.3401 - dense_5_loss: 15.7283 - dense_6_loss: 16.1142 - dense_1_categorical_accuracy: 0.1050 - dense_2_categorical_accuracy: 0.0973 - dense_3_categorical_accuracy: 0.0572 - dense_4_categorical_accuracy: 0.0064 - dense_5_categorical_accuracy: 6.7112e-05 - dense_6_categorical_accuracy: 0.7576 - val_loss: 54.9901 - val_dense_1_loss: 8.9851 - val_dense_2_loss: 7.3044 - val_dense_3_loss: 5.8905 - val_dense_4_loss: 0.5806 - val_dense_5_loss: 16.1113 - val_dense_6_loss: 16.1181 - val_dense_1_categorical_accuracy: 0.1965 - val_dense_2_categorical_accuracy: 0.1020 - val_dense_3_categorical_accuracy: 0.0758 - val_dense_4_categorical_accuracy: 0.0057 - val_dense_5_categorical_accuracy: 5.4909e-05 - val_dense_6_categorical_accuracy: 0.0000e+00
# Epoch 3/100
# 5123/5123 - 51s - loss: 66.8411 - dense_1_loss: 0.8936 - dense_2_loss: 8.4494 - dense_3_loss: 11.8990 - dense_4_loss: 13.8332 - dense_5_loss: 15.6597 - dense_6_loss: 16.1045 - dense_1_categorical_accuracy: 0.0230 - dense_2_categorical_accuracy: 0.0999 - dense_3_categorical_accuracy: 0.3651 - dense_4_categorical_accuracy: 0.0115 - dense_5_categorical_accuracy: 2.4404e-04 - dense_6_categorical_accuracy: 0.0108 - val_loss: 68.7803 - val_dense_1_loss: 1.1921e-07 - val_dense_2_loss: 8.4885 - val_dense_3_loss: 12.6656 - val_dense_4_loss: 15.3935 - val_dense_5_loss: 16.1146 - val_dense_6_loss: 16.1181 - val_dense_1_categorical_accuracy: 0.0025 - val_dense_2_categorical_accuracy: 0.0983 - val_dense_3_categorical_accuracy: 0.3997 - val_dense_4_categorical_accuracy: 0.0110 - val_dense_5_categorical_accuracy: 0.0000e+00 - val_dense_6_categorical_accuracy: 0.0000e+00
# Epoch 4/100
# 5123/5123 - 51s - loss: 68.7811 - dense_1_loss: 1.1921e-07 - dense_2_loss: 8.5849 - dense_3_loss: 12.5961 - dense_4_loss: 15.3676 - dense_5_loss: 16.1137 - dense_6_loss: 16.1174 - dense_1_categorical_accuracy: 0.0026 - dense_2_categorical_accuracy: 0.0992 - dense_3_categorical_accuracy: 0.4007 - dense_4_categorical_accuracy: 0.0122 - dense_5_categorical_accuracy: 4.2708e-05 - dense_6_categorical_accuracy: 0.0000e+00 - val_loss: 68.7803 - val_dense_1_loss: 1.1921e-07 - val_dense_2_loss: 8.4885 - val_dense_3_loss: 12.6656 - val_dense_4_loss: 15.3935 - val_dense_5_loss: 16.1146 - val_dense_6_loss: 16.1181 - val_dense_1_categorical_accuracy: 0.0025 - val_dense_2_categorical_accuracy: 0.0983 - val_dense_3_categorical_accuracy: 0.3997 - val_dense_4_categorical_accuracy: 0.0110 - val_dense_5_categorical_accuracy: 0.0000e+00 - val_dense_6_categorical_accuracy: 0.0000e+00
# Epoch 5/100
# 5123/5123 - 52s - loss: 68.7843 - dense_1_loss: 1.1921e-07 - dense_2_loss: 8.5879 - dense_3_loss: 12.5961 - dense_4_loss: 15.3676 - dense_5_loss: 16.1137 - dense_6_loss: 16.1174 - dense_1_categorical_accuracy: 0.0026 - dense_2_categorical_accuracy: 0.0992 - dense_3_categorical_accuracy: 0.4007 - dense_4_categorical_accuracy: 0.0122 - dense_5_categorical_accuracy: 4.2708e-05 - dense_6_categorical_accuracy: 0.0000e+00 - val_loss: 68.7803 - val_dense_1_loss: 1.1921e-07 - val_dense_2_loss: 8.4885 - val_dense_3_loss: 12.6656 - val_dense_4_loss: 15.3935 - val_dense_5_loss: 16.1146 - val_dense_6_loss: 16.1181 - val_dense_1_categorical_accuracy: 0.0025 - val_dense_2_categorical_accuracy: 0.0983 - val_dense_3_categorical_accuracy: 0.3997 - val_dense_4_categorical_accuracy: 0.0110 - val_dense_5_categorical_accuracy: 0.0000e+00 - val_dense_6_categorical_accuracy: 0.0000e+00
# Epoch 6/100
# 5123/5123 - 51s - loss: 68.7811 - dense_1_loss: 1.1921e-07 - dense_2_loss: 8.5849 - dense_3_loss: 12.5961 - dense_4_loss: 15.3676 - dense_5_loss: 16.1138 - dense_6_loss: 16.1174 - dense_1_categorical_accuracy: 0.0026 - dense_2_categorical_accuracy: 0.0992 - dense_3_categorical_accuracy: 0.4007 - dense_4_categorical_accuracy: 0.0122 - dense_5_categorical_accuracy: 4.2708e-05 - dense_6_categorical_accuracy: 0.0000e+00 - val_loss: 68.7803 - val_dense_1_loss: 1.1921e-07 - val_dense_2_loss: 8.4885 - val_dense_3_loss: 12.6656 - val_dense_4_loss: 15.3935 - val_dense_5_loss: 16.1146 - val_dense_6_loss: 16.1181 - val_dense_1_categorical_accuracy: 0.0025 - val_dense_2_categorical_accuracy: 0.0983 - val_dense_3_categorical_accuracy: 0.3997 - val_dense_4_categorical_accuracy: 0.0110 - val_dense_5_categorical_accuracy: 0.0000e+00 - val_dense_6_categorical_accuracy: 0.0000e+00
# Epoch 7/100
# 5123/5123 - 51s - loss: 68.7780 - dense_1_loss: 1.1921e-07 - dense_2_loss: 8.5849 - dense_3_loss: 12.5961 - dense_4_loss: 15.3646 - dense_5_loss: 16.1137 - dense_6_loss: 16.1174 - dense_1_categorical_accuracy: 0.0026 - dense_2_categorical_accuracy: 0.0992 - dense_3_categorical_accuracy: 0.4007 - dense_4_categorical_accuracy: 0.0122 - dense_5_categorical_accuracy: 4.2708e-05 - dense_6_categorical_accuracy: 0.0000e+00 - val_loss: 68.7803 - val_dense_1_loss: 1.1921e-07 - val_dense_2_loss: 8.4885 - val_dense_3_loss: 12.6656 - val_dense_4_loss: 15.3935 - val_dense_5_loss: 16.1146 - val_dense_6_loss: 16.1181 - val_dense_1_categorical_accuracy: 0.0025 - val_dense_2_categorical_accuracy: 0.0983 - val_dense_3_categorical_accuracy: 0.3997 - val_dense_4_categorical_accuracy: 0.0110 - val_dense_5_categorical_accuracy: 0.0000e+00 - val_dense_6_categorical_accuracy: 0.0000e+00
# Epoch 8/100
# 5123/5123 - 51s - loss: 68.7811 - dense_1_loss: 1.1921e-07 - dense_2_loss: 8.5849 - dense_3_loss: 12.5961 - dense_4_loss: 15.3676 - dense_5_loss: 16.1137 - dense_6_loss: 16.1174 - dense_1_categorical_accuracy: 0.0026 - dense_2_categorical_accuracy: 0.0992 - dense_3_categorical_accuracy: 0.4007 - dense_4_categorical_accuracy: 0.0122 - dense_5_categorical_accuracy: 4.2708e-05 - dense_6_categorical_accuracy: 0.0000e+00 - val_loss: 68.7803 - val_dense_1_loss: 1.1921e-07 - val_dense_2_loss: 8.4885 - val_dense_3_loss: 12.6656 - val_dense_4_loss: 15.3935 - val_dense_5_loss: 16.1146 - val_dense_6_loss: 16.1181 - val_dense_1_categorical_accuracy: 0.0025 - val_dense_2_categorical_accuracy: 0.0983 - val_dense_3_categorical_accuracy: 0.3997 - val_dense_4_categorical_accuracy: 0.0110 - val_dense_5_categorical_accuracy: 0.0000e+00 - val_dense_6_categorical_accuracy: 0.0000e+00
# Epoch 9/100
# 5123/5123 - 51s - loss: 68.7812 - dense_1_loss: 1.1921e-07 - dense_2_loss: 8.5849 - dense_3_loss: 12.5961 - dense_4_loss: 15.3676 - dense_5_loss: 16.1137 - dense_6_loss: 16.1174 - dense_1_categorical_accuracy: 0.0026 - dense_2_categorical_accuracy: 0.0992 - dense_3_categorical_accuracy: 0.4007 - dense_4_categorical_accuracy: 0.0122 - dense_5_categorical_accuracy: 4.2708e-05 - dense_6_categorical_accuracy: 0.0000e+00 - val_loss: 68.7803 - val_dense_1_loss: 1.1921e-07 - val_dense_2_loss: 8.4885 - val_dense_3_loss: 12.6656 - val_dense_4_loss: 15.3935 - val_dense_5_loss: 16.1146 - val_dense_6_loss: 16.1181 - val_dense_1_categorical_accuracy: 0.0025 - val_dense_2_categorical_accuracy: 0.0983 - val_dense_3_categorical_accuracy: 0.3997 - val_dense_4_categorical_accuracy: 0.0110 - val_dense_5_categorical_accuracy: 0.0000e+00 - val_dense_6_categorical_accuracy: 0.0000e+00
# Epoch 10/100
# 5123/5123 - 51s - loss: 68.7842 - dense_1_loss: 1.1921e-07 - dense_2_loss: 8.5879 - dense_3_loss: 12.5961 - dense_4_loss: 15.3676 - dense_5_loss: 16.1137 - dense_6_loss: 16.1174 - dense_1_categorical_accuracy: 0.0026 - dense_2_categorical_accuracy: 0.0992 - dense_3_categorical_accuracy: 0.4007 - dense_4_categorical_accuracy: 0.0122 - dense_5_categorical_accuracy: 4.2708e-05 - dense_6_categorical_accuracy: 0.0000e+00 - val_loss: 68.7803 - val_dense_1_loss: 1.1921e-07 - val_dense_2_loss: 8.4885 - val_dense_3_loss: 12.6656 - val_dense_4_loss: 15.3935 - val_dense_5_loss: 16.1146 - val_dense_6_loss: 16.1181 - val_dense_1_categorical_accuracy: 0.0025 - val_dense_2_categorical_accuracy: 0.0983 - val_dense_3_categorical_accuracy: 0.3997 - val_dense_4_categorical_accuracy: 0.0110 - val_dense_5_categorical_accuracy: 0.0000e+00 - val_dense_6_categorical_accuracy: 0.0000e+00
# Epoch 11/100
# 5123/5123 - 51s - loss: 68.7842 - dense_1_loss: 1.1921e-07 - dense_2_loss: 8.5879 - dense_3_loss: 12.5961 - dense_4_loss: 15.3676 - dense_5_loss: 16.1138 - dense_6_loss: 16.1174 - dense_1_categorical_accuracy: 0.0026 - dense_2_categorical_accuracy: 0.0992 - dense_3_categorical_accuracy: 0.4007 - dense_4_categorical_accuracy: 0.0122 - dense_5_categorical_accuracy: 4.2708e-05 - dense_6_categorical_accuracy: 0.0000e+00 - val_loss: 68.7803 - val_dense_1_loss: 1.1921e-07 - val_dense_2_loss: 8.4885 - val_dense_3_loss: 12.6656 - val_dense_4_loss: 15.3935 - val_dense_5_loss: 16.1146 - val_dense_6_loss: 16.1181 - val_dense_1_categorical_accuracy: 0.0025 - val_dense_2_categorical_accuracy: 0.0983 - val_dense_3_categorical_accuracy: 0.3997 - val_dense_4_categorical_accuracy: 0.0110 - val_dense_5_categorical_accuracy: 0.0000e+00 - val_dense_6_categorical_accuracy: 0.0000e+00
# Epoch 12/100
# 5123/5123 - 51s - loss: 68.7811 - dense_1_loss: 1.1921e-07 - dense_2_loss: 8.5879 - dense_3_loss: 12.5931 - dense_4_loss: 15.3676 - dense_5_loss: 16.1138 - dense_6_loss: 16.1174 - dense_1_categorical_accuracy: 0.0026 - dense_2_categorical_accuracy: 0.0992 - dense_3_categorical_accuracy: 0.4007 - dense_4_categorical_accuracy: 0.0122 - dense_5_categorical_accuracy: 4.2708e-05 - dense_6_categorical_accuracy: 0.0000e+00 - val_loss: 68.7803 - val_dense_1_loss: 1.1921e-07 - val_dense_2_loss: 8.4885 - val_dense_3_loss: 12.6656 - val_dense_4_loss: 15.3935 - val_dense_5_loss: 16.1146 - val_dense_6_loss: 16.1181 - val_dense_1_categorical_accuracy: 0.0025 - val_dense_2_categorical_accuracy: 0.0983 - val_dense_3_categorical_accuracy: 0.3997 - val_dense_4_categorical_accuracy: 0.0110 - val_dense_5_categorical_accuracy: 0.0000e+00 - val_dense_6_categorical_accuracy: 0.0000e+00

# %%
y_pred = model.predict(x_test)

total = np.array([True] * len(x_test))
for i, (y1, y2) in enumerate(zip(y_test, y_pred)):
  cur = np.argmax(y1, axis=1) == np.argmax(y2, axis=1)
  total = np.logical_and(total, cur)

  acc = np.mean(cur.astype(np.int))
  #history[f'test_out_{i}_acc'] = acc
  print(f'Accuracy of out_{i} = {acc:.5f}')

acc = np.mean(total.astype(np.int))
#history['test_acc'] = acc
print(f'Accuracy = {acc:.5f}')
# Out:
# Accuracy of out_0 = 0.20332
# Accuracy of out_1 = 0.07859
# Accuracy of out_2 = 0.01852
# Accuracy of out_3 = 0.00122
# Accuracy of out_4 = 0.00000
# Accuracy of out_5 = 0.00000
# Accuracy = 0.00000

# %%
input = keras.layers.Input(shape=(96, 96, 3))

mobile_net = keras.applications.mobilenet_v2.MobileNetV2(
  include_top=False,
  weights='imagenet',
  input_shape=(96, 96, 3),
  input_tensor=input,
  pooling='avg'
)

dropout = keras.layers.Dropout(rate=0.1)(mobile_net.output)

outputs = [
  keras.layers.Dense(11, activation='softmax', name=f'out_{i}')(dropout)
  for i in range(6)
]

model1 = keras.models.Model(
  inputs=[input],
  outputs=outputs
)
model1.compile(
  optimizer=keras.optimizers.Adam(lr=0.001),
  loss='categorical_crossentropy',
  metrics=['categorical_accuracy'],
  loss_weights=[1, 1, 0.5, 0.3, 0.1, 0.05]
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_96_no_top.h5
# 9412608/9406464 [==============================] - 0s 0us/step

# %%
model.fit(
                x_train,
                y_train,
                epochs=100,
                batch_size=32,
                verbose=2,
                validation_split=0.1,
                callbacks=[
                    keras.callbacks.EarlyStopping(
                        patience=10,
                        restore_best_weights=True
                    )
                ]
            )
# Out:
# Epoch 1/100
# 5123/5123 - 51s - loss: 46.1482 - dense_1_loss: 0.0013 - dense_2_loss: 8.5820 - dense_3_loss: 5.8069 - dense_4_loss: 0.9042 - dense_5_loss: 14.7355 - dense_6_loss: 16.1174 - dense_1_categorical_accuracy: 0.0027 - dense_2_categorical_accuracy: 0.0993 - dense_3_categorical_accuracy: 0.4006 - dense_4_categorical_accuracy: 0.0067 - dense_5_categorical_accuracy: 1.8303e-05 - dense_6_categorical_accuracy: 0.9998 - val_loss: 47.2816 - val_dense_1_loss: 1.1921e-07 - val_dense_2_loss: 8.4885 - val_dense_3_loss: 5.7571 - val_dense_4_loss: 0.8050 - val_dense_5_loss: 16.1128 - val_dense_6_loss: 16.1181 - val_dense_1_categorical_accuracy: 0.0025 - val_dense_2_categorical_accuracy: 0.0983 - val_dense_3_categorical_accuracy: 0.3997 - val_dense_4_categorical_accuracy: 0.0065 - val_dense_5_categorical_accuracy: 0.0000e+00 - val_dense_6_categorical_accuracy: 1.0000
# Epoch 2/100
# 5123/5123 - 51s - loss: 47.4463 - dense_1_loss: 1.1921e-07 - dense_2_loss: 8.5879 - dense_3_loss: 5.7935 - dense_4_loss: 0.8329 - dense_5_loss: 16.1135 - dense_6_loss: 16.1174 - dense_1_categorical_accuracy: 0.0026 - dense_2_categorical_accuracy: 0.0992 - dense_3_categorical_accuracy: 0.4007 - dense_4_categorical_accuracy: 0.0067 - dense_5_categorical_accuracy: 2.4404e-05 - dense_6_categorical_accuracy: 1.0000 - val_loss: 47.2816 - val_dense_1_loss: 1.1921e-07 - val_dense_2_loss: 8.4885 - val_dense_3_loss: 5.7571 - val_dense_4_loss: 0.8050 - val_dense_5_loss: 16.1128 - val_dense_6_loss: 16.1181 - val_dense_1_categorical_accuracy: 0.0025 - val_dense_2_categorical_accuracy: 0.0983 - val_dense_3_categorical_accuracy: 0.3997 - val_dense_4_categorical_accuracy: 0.0065 - val_dense_5_categorical_accuracy: 0.0000e+00 - val_dense_6_categorical_accuracy: 1.0000
# Epoch 3/100
# 5123/5123 - 51s - loss: 47.4463 - dense_1_loss: 1.1921e-07 - dense_2_loss: 8.5879 - dense_3_loss: 5.7905 - dense_4_loss: 0.8360 - dense_5_loss: 16.1135 - dense_6_loss: 16.1174 - dense_1_categorical_accuracy: 0.0026 - dense_2_categorical_accuracy: 0.0992 - dense_3_categorical_accuracy: 0.4007 - dense_4_categorical_accuracy: 0.0067 - dense_5_categorical_accuracy: 2.4404e-05 - dense_6_categorical_accuracy: 1.0000 - val_loss: 47.2816 - val_dense_1_loss: 1.1921e-07 - val_dense_2_loss: 8.4885 - val_dense_3_loss: 5.7571 - val_dense_4_loss: 0.8050 - val_dense_5_loss: 16.1128 - val_dense_6_loss: 16.1181 - val_dense_1_categorical_accuracy: 0.0025 - val_dense_2_categorical_accuracy: 0.0983 - val_dense_3_categorical_accuracy: 0.3997 - val_dense_4_categorical_accuracy: 0.0065 - val_dense_5_categorical_accuracy: 0.0000e+00 - val_dense_6_categorical_accuracy: 1.0000
# Epoch 4/100
# 5123/5123 - 51s - loss: 47.4402 - dense_1_loss: 1.1921e-07 - dense_2_loss: 8.5849 - dense_3_loss: 5.7905 - dense_4_loss: 0.8329 - dense_5_loss: 16.1135 - dense_6_loss: 16.1174 - dense_1_categorical_accuracy: 0.0026 - dense_2_categorical_accuracy: 0.0992 - dense_3_categorical_accuracy: 0.4007 - dense_4_categorical_accuracy: 0.0067 - dense_5_categorical_accuracy: 2.4404e-05 - dense_6_categorical_accuracy: 1.0000 - val_loss: 47.2816 - val_dense_1_loss: 1.1921e-07 - val_dense_2_loss: 8.4885 - val_dense_3_loss: 5.7571 - val_dense_4_loss: 0.8050 - val_dense_5_loss: 16.1128 - val_dense_6_loss: 16.1181 - val_dense_1_categorical_accuracy: 0.0025 - val_dense_2_categorical_accuracy: 0.0983 - val_dense_3_categorical_accuracy: 0.3997 - val_dense_4_categorical_accuracy: 0.0065 - val_dense_5_categorical_accuracy: 0.0000e+00 - val_dense_6_categorical_accuracy: 1.0000
# Epoch 5/100
# 5123/5123 - 51s - loss: 47.4433 - dense_1_loss: 1.1921e-07 - dense_2_loss: 8.5879 - dense_3_loss: 5.7905 - dense_4_loss: 0.8329 - dense_5_loss: 16.1135 - dense_6_loss: 16.1174 - dense_1_categorical_accuracy: 0.0026 - dense_2_categorical_accuracy: 0.0992 - dense_3_categorical_accuracy: 0.4007 - dense_4_categorical_accuracy: 0.0067 - dense_5_categorical_accuracy: 2.4404e-05 - dense_6_categorical_accuracy: 1.0000 - val_loss: 47.2816 - val_dense_1_loss: 1.1921e-07 - val_dense_2_loss: 8.4885 - val_dense_3_loss: 5.7571 - val_dense_4_loss: 0.8050 - val_dense_5_loss: 16.1128 - val_dense_6_loss: 16.1181 - val_dense_1_categorical_accuracy: 0.0025 - val_dense_2_categorical_accuracy: 0.0983 - val_dense_3_categorical_accuracy: 0.3997 - val_dense_4_categorical_accuracy: 0.0065 - val_dense_5_categorical_accuracy: 0.0000e+00 - val_dense_6_categorical_accuracy: 1.0000
# Epoch 6/100
# 5123/5123 - 51s - loss: 47.4432 - dense_1_loss: 1.1921e-07 - dense_2_loss: 8.5849 - dense_3_loss: 5.7905 - dense_4_loss: 0.8360 - dense_5_loss: 16.1135 - dense_6_loss: 16.1174 - dense_1_categorical_accuracy: 0.0026 - dense_2_categorical_accuracy: 0.0992 - dense_3_categorical_accuracy: 0.4007 - dense_4_categorical_accuracy: 0.0067 - dense_5_categorical_accuracy: 2.4404e-05 - dense_6_categorical_accuracy: 1.0000 - val_loss: 47.2816 - val_dense_1_loss: 1.1921e-07 - val_dense_2_loss: 8.4885 - val_dense_3_loss: 5.7571 - val_dense_4_loss: 0.8050 - val_dense_5_loss: 16.1128 - val_dense_6_loss: 16.1181 - val_dense_1_categorical_accuracy: 0.0025 - val_dense_2_categorical_accuracy: 0.0983 - val_dense_3_categorical_accuracy: 0.3997 - val_dense_4_categorical_accuracy: 0.0065 - val_dense_5_categorical_accuracy: 0.0000e+00 - val_dense_6_categorical_accuracy: 1.0000
# Epoch 7/100
# 5123/5123 - 51s - loss: 47.4433 - dense_1_loss: 1.1921e-07 - dense_2_loss: 8.5879 - dense_3_loss: 5.7905 - dense_4_loss: 0.8329 - dense_5_loss: 16.1135 - dense_6_loss: 16.1174 - dense_1_categorical_accuracy: 0.0026 - dense_2_categorical_accuracy: 0.0992 - dense_3_categorical_accuracy: 0.4007 - dense_4_categorical_accuracy: 0.0067 - dense_5_categorical_accuracy: 2.4404e-05 - dense_6_categorical_accuracy: 1.0000 - val_loss: 47.2816 - val_dense_1_loss: 1.1921e-07 - val_dense_2_loss: 8.4885 - val_dense_3_loss: 5.7571 - val_dense_4_loss: 0.8050 - val_dense_5_loss: 16.1128 - val_dense_6_loss: 16.1181 - val_dense_1_categorical_accuracy: 0.0025 - val_dense_2_categorical_accuracy: 0.0983 - val_dense_3_categorical_accuracy: 0.3997 - val_dense_4_categorical_accuracy: 0.0065 - val_dense_5_categorical_accuracy: 0.0000e+00 - val_dense_6_categorical_accuracy: 1.0000
# Epoch 8/100
# 5123/5123 - 51s - loss: 47.4433 - dense_1_loss: 1.1921e-07 - dense_2_loss: 8.5879 - dense_3_loss: 5.7905 - dense_4_loss: 0.8329 - dense_5_loss: 16.1135 - dense_6_loss: 16.1174 - dense_1_categorical_accuracy: 0.0026 - dense_2_categorical_accuracy: 0.0992 - dense_3_categorical_accuracy: 0.4007 - dense_4_categorical_accuracy: 0.0067 - dense_5_categorical_accuracy: 2.4404e-05 - dense_6_categorical_accuracy: 1.0000 - val_loss: 47.2816 - val_dense_1_loss: 1.1921e-07 - val_dense_2_loss: 8.4885 - val_dense_3_loss: 5.7571 - val_dense_4_loss: 0.8050 - val_dense_5_loss: 16.1128 - val_dense_6_loss: 16.1181 - val_dense_1_categorical_accuracy: 0.0025 - val_dense_2_categorical_accuracy: 0.0983 - val_dense_3_categorical_accuracy: 0.3997 - val_dense_4_categorical_accuracy: 0.0065 - val_dense_5_categorical_accuracy: 0.0000e+00 - val_dense_6_categorical_accuracy: 1.0000
# Epoch 9/100
# 5123/5123 - 51s - loss: 47.4463 - dense_1_loss: 1.1921e-07 - dense_2_loss: 8.5879 - dense_3_loss: 5.7935 - dense_4_loss: 0.8329 - dense_5_loss: 16.1135 - dense_6_loss: 16.1174 - dense_1_categorical_accuracy: 0.0026 - dense_2_categorical_accuracy: 0.0992 - dense_3_categorical_accuracy: 0.4007 - dense_4_categorical_accuracy: 0.0067 - dense_5_categorical_accuracy: 2.4404e-05 - dense_6_categorical_accuracy: 1.0000 - val_loss: 47.2816 - val_dense_1_loss: 1.1921e-07 - val_dense_2_loss: 8.4885 - val_dense_3_loss: 5.7571 - val_dense_4_loss: 0.8050 - val_dense_5_loss: 16.1128 - val_dense_6_loss: 16.1181 - val_dense_1_categorical_accuracy: 0.0025 - val_dense_2_categorical_accuracy: 0.0983 - val_dense_3_categorical_accuracy: 0.3997 - val_dense_4_categorical_accuracy: 0.0065 - val_dense_5_categorical_accuracy: 0.0000e+00 - val_dense_6_categorical_accuracy: 1.0000
# Epoch 10/100
# 5123/5123 - 51s - loss: 47.4462 - dense_1_loss: 1.1921e-07 - dense_2_loss: 8.5879 - dense_3_loss: 5.7935 - dense_4_loss: 0.8329 - dense_5_loss: 16.1135 - dense_6_loss: 16.1174 - dense_1_categorical_accuracy: 0.0026 - dense_2_categorical_accuracy: 0.0992 - dense_3_categorical_accuracy: 0.4007 - dense_4_categorical_accuracy: 0.0067 - dense_5_categorical_accuracy: 2.4404e-05 - dense_6_categorical_accuracy: 1.0000 - val_loss: 47.2816 - val_dense_1_loss: 1.1921e-07 - val_dense_2_loss: 8.4885 - val_dense_3_loss: 5.7571 - val_dense_4_loss: 0.8050 - val_dense_5_loss: 16.1128 - val_dense_6_loss: 16.1181 - val_dense_1_categorical_accuracy: 0.0025 - val_dense_2_categorical_accuracy: 0.0983 - val_dense_3_categorical_accuracy: 0.3997 - val_dense_4_categorical_accuracy: 0.0065 - val_dense_5_categorical_accuracy: 0.0000e+00 - val_dense_6_categorical_accuracy: 1.0000
# Epoch 11/100
# 5123/5123 - 51s - loss: 47.4402 - dense_1_loss: 1.1921e-07 - dense_2_loss: 8.5849 - dense_3_loss: 5.7905 - dense_4_loss: 0.8329 - dense_5_loss: 16.1135 - dense_6_loss: 16.1174 - dense_1_categorical_accuracy: 0.0026 - dense_2_categorical_accuracy: 0.0992 - dense_3_categorical_accuracy: 0.4007 - dense_4_categorical_accuracy: 0.0067 - dense_5_categorical_accuracy: 2.4404e-05 - dense_6_categorical_accuracy: 1.0000 - val_loss: 47.2816 - val_dense_1_loss: 1.1921e-07 - val_dense_2_loss: 8.4885 - val_dense_3_loss: 5.7571 - val_dense_4_loss: 0.8050 - val_dense_5_loss: 16.1128 - val_dense_6_loss: 16.1181 - val_dense_1_categorical_accuracy: 0.0025 - val_dense_2_categorical_accuracy: 0.0983 - val_dense_3_categorical_accuracy: 0.3997 - val_dense_4_categorical_accuracy: 0.0065 - val_dense_5_categorical_accuracy: 0.0000e+00 - val_dense_6_categorical_accuracy: 1.0000

# %%
y_pred = model1.predict(x_test)

total = np.array([True] * len(x_test))
for i, (y1, y2) in enumerate(zip(y_test, y_pred)):
  cur = np.argmax(y1, axis=1) == np.argmax(y2, axis=1)
  total = np.logical_and(total, cur)

  acc = np.mean(cur.astype(np.int))
  #history[f'test_out_{i}_acc'] = acc
  print(f'Accuracy of out_{i} = {acc:.5f}')

acc = np.mean(total.astype(np.int))
#history['test_acc'] = acc
print(f'Accuracy = {acc:.5f}')
# Out:
# Accuracy of out_0 = 0.03972
# Accuracy of out_1 = 0.15810
# Accuracy of out_2 = 0.04966
# Accuracy of out_3 = 0.00964
# Accuracy of out_4 = 0.30081
# Accuracy of out_5 = 0.00031
# Accuracy = 0.00000

# %%
model.save_weights('models/svhn_multiple_mobile_net_extra/model')

# %%
# !ls models/svhn_multiple_mobile_net_extra/
# Out:
# checkpoint  model.data-00000-of-00002  model.data-00001-of-00002  model.index
