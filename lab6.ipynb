# %%
# Install Kaggle library
# !pip install -q kaggle

import os
os.environ['KAGGLE_USERNAME'] = "katetuzina" # username from the json file
os.environ['KAGGLE_KEY'] = "7578fa8dde4c34ef17a35fab34c9b088" # key from the json file
#!kaggle datasets download -d iarunava/happy-house-dataset # api copied from kaggle
# !kaggle datasets download -d datamunge/sign-language-mnist
# Out:
# Downloading sign-language-mnist.zip to /content
#  81% 51.0M/62.6M [00:01<00:00, 22.2MB/s]
# 100% 62.6M/62.6M [00:01<00:00, 47.9MB/s]

# %%
# !ls
# Out:
# sample_data  sign-language-mnist.zip

# %%
# !unzip sign-language-mnist.zip
# Out:
# Archive:  sign-language-mnist.zip
#   inflating: amer_sign2.png
#   inflating: amer_sign3.png
#   inflating: american_sign_language.PNG
#   inflating: sign_mnist_test.csv
#   inflating: sign_mnist_test/sign_mnist_test.csv
#   inflating: sign_mnist_train.csv
#   inflating: sign_mnist_train/sign_mnist_train.csv

# %%
# !ls
# Out:
# american_sign_language.PNG  sample_data		     sign_mnist_test.csv
# amer_sign2.png		    sign-language-mnist.zip  sign_mnist_train
# amer_sign3.png		    sign_mnist_test	     sign_mnist_train.csv

# %%
import pandas as pd
df = pd.read_csv('sign_mnist_train.csv')
print(df)

testDF = pd.read_csv('sign_mnist_test.csv')
print(testDF)
# Out:
#        label  pixel1  pixel2  pixel3  ...  pixel781  pixel782  pixel783  pixel784
# 0          3     107     118     127  ...       206       204       203       202
# 1          6     155     157     156  ...       175       103       135       149
# 2          2     187     188     188  ...       198       195       194       195
# 3          2     211     211     212  ...       225       222       229       163
# 4         13     164     167     170  ...       157       163       164       179
# ...      ...     ...     ...     ...  ...       ...       ...       ...       ...
# 27450     13     189     189     190  ...       234       200       222       225
# 27451     23     151     154     157  ...       195       195       195       194
# 27452     18     174     174     174  ...       203       202       200       200
# 27453     17     177     181     184  ...        47        64        87        93
# 27454     23     179     180     180  ...       197       205       209       215
#
# [27455 rows x 785 columns]
#       label  pixel1  pixel2  pixel3  ...  pixel781  pixel782  pixel783  pixel784
# 0         6     149     149     150  ...       106       112       120       107
# 1         5     126     128     131  ...       184       184       182       180
# 2        10      85      88      92  ...       226       225       224       222
# 3         0     203     205     207  ...       230       240       253       255
# 4         3     188     191     193  ...        49        46        46        53
# ...     ...     ...     ...     ...  ...       ...       ...       ...       ...
# 7167      1     135     119     108  ...       184       176       167       163
# 7168     12     157     159     161  ...       210       210       209       208
# 7169      2     190     191     190  ...       210       211       209       208
# 7170      4     201     205     208  ...        91        67        70        63
# 7171      2     173     174     173  ...       195       195       193       192
#
# [7172 rows x 785 columns]

# %%
def getData(df):
  y = df["label"].values.reshape((df.shape[0], 1)) 
  x = df.drop(columns="label").values.reshape((df.shape[0], 28, 28, 1))
  print(y.shape, x.shape)
  return x, y

x, y = getData(df)
tX, tY = getData(testDF)
# Out:
# (27455, 1) (27455, 28, 28, 1)
# (7172, 1) (7172, 28, 28, 1)

# %%
from sklearn.model_selection import train_test_split
x_train, x_val, y_train, y_val = train_test_split(x, y, test_size=.25)

# %%
from tensorflow.keras import layers, models, Sequential

model = Sequential([
    layers.Conv2D(64, kernel_size=3, activation='relu', input_shape=(28,28,1)),
    layers.Conv2D(32, kernel_size=5, activation='relu'),
    layers.Dropout(0.25),
    layers.MaxPooling2D((2, 2)),
    layers.Conv2D(64, (3, 3), activation='relu', padding='same'),
    layers.Dropout(0.25),
    layers.MaxPooling2D((2, 2)),
    layers.Conv2D(128, (3, 3), activation='relu', padding='same'),
    layers.Dropout(0.25),
    layers.MaxPooling2D((2, 2)),
    layers.Flatten(),
    layers.Dense(500, activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(25, activation='softmax')
])

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
import tensorflow as tf

model.fit(x_train, y_train, validation_split=0.1, epochs=10)
# Out:
# Epoch 1/10
# 580/580 [==============================] - 3s 5ms/step - loss: 2.2607 - accuracy: 0.3412 - val_loss: 0.7509 - val_accuracy: 0.8398
# Epoch 2/10
# 580/580 [==============================] - 3s 5ms/step - loss: 0.4768 - accuracy: 0.8363 - val_loss: 0.1927 - val_accuracy: 0.9786
# Epoch 3/10
# 580/580 [==============================] - 3s 5ms/step - loss: 0.2261 - accuracy: 0.9236 - val_loss: 0.0417 - val_accuracy: 0.9947
# Epoch 4/10
# 580/580 [==============================] - 3s 5ms/step - loss: 0.1756 - accuracy: 0.9436 - val_loss: 0.0328 - val_accuracy: 0.9995
# Epoch 5/10
# 580/580 [==============================] - 3s 5ms/step - loss: 0.1281 - accuracy: 0.9599 - val_loss: 0.0350 - val_accuracy: 0.9961
# Epoch 6/10
# 580/580 [==============================] - 3s 5ms/step - loss: 0.1155 - accuracy: 0.9624 - val_loss: 0.0205 - val_accuracy: 0.9985
# Epoch 7/10
# 580/580 [==============================] - 3s 5ms/step - loss: 0.1005 - accuracy: 0.9682 - val_loss: 0.0144 - val_accuracy: 0.9981
# Epoch 8/10
# 580/580 [==============================] - 3s 5ms/step - loss: 0.0969 - accuracy: 0.9703 - val_loss: 0.0112 - val_accuracy: 0.9985
# Epoch 9/10
# 580/580 [==============================] - 3s 5ms/step - loss: 0.1009 - accuracy: 0.9693 - val_loss: 0.0107 - val_accuracy: 0.9995
# Epoch 10/10
# 580/580 [==============================] - 3s 5ms/step - loss: 0.0779 - accuracy: 0.9753 - val_loss: 0.0137 - val_accuracy: 0.9985

# %%
model.evaluate(tX,  tY)
# Out:
# 225/225 [==============================] - 1s 3ms/step - loss: 0.1241 - accuracy: 0.9582
# [0.12410242110490799, 0.9581706523895264]

# %%
model = Sequential([
    layers.Conv2D(64, kernel_size=3, activation='relu', input_shape=(28,28,1)),
    layers.Conv2D(32, kernel_size=5, activation='relu'),
    layers.Dropout(0.25),
    layers.MaxPooling2D((2, 2)),
    layers.Conv2D(64, (3, 3), activation='relu', padding='same'),
    layers.Dropout(0.25),
    layers.MaxPooling2D((2, 2)),
    layers.Conv2D(128, (3, 3), activation='relu', padding='same'),
    layers.Dropout(0.25),
    layers.MaxPooling2D((2, 2)),
    layers.Flatten(),
    layers.Dense(500, activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(25, activation='softmax')
])

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator


datagen = ImageDataGenerator(rotation_range=20, zoom_range=0.15,
	width_shift_range=0.2, height_shift_range=0.2, shear_range=0.15,
	horizontal_flip=True, fill_mode="nearest")

train_generator = datagen.flow(x_train, y_train, batch_size=32)
val_generator = datagen.flow(x_val, y_val, batch_size=32)
test_generator = datagen.flow(tX, tY, batch_size=32)

# %%
model.fit_generator(
  train_generator,
  epochs=10,
  validation_data=(x_val,y_val), steps_per_epoch=len(x_train) // 32)
# Out:
# Epoch 1/10
# 643/643 [==============================] - 10s 16ms/step - loss: 3.2705 - accuracy: 0.0558 - val_loss: 2.8013 - val_accuracy: 0.0147
# Epoch 2/10
# 643/643 [==============================] - 10s 16ms/step - loss: 2.8239 - accuracy: 0.0238 - val_loss: 2.5648 - val_accuracy: 0.0424
# Epoch 3/10
# 643/643 [==============================] - 10s 15ms/step - loss: 2.6036 - accuracy: 0.0491 - val_loss: 2.1897 - val_accuracy: 0.0495
# Epoch 4/10
# 643/643 [==============================] - 10s 15ms/step - loss: 2.2200 - accuracy: 0.0565 - val_loss: 1.8211 - val_accuracy: 0.0747
# Epoch 5/10
# 643/643 [==============================] - 10s 15ms/step - loss: 1.8037 - accuracy: 0.0510 - val_loss: 1.1688 - val_accuracy: 0.0948
# Epoch 6/10
# 643/643 [==============================] - 10s 16ms/step - loss: 1.5083 - accuracy: 0.0509 - val_loss: 0.8367 - val_accuracy: 0.0777
# Epoch 7/10
# 643/643 [==============================] - 10s 15ms/step - loss: 1.3101 - accuracy: 0.0462 - val_loss: 0.6321 - val_accuracy: 0.0548
# Epoch 8/10
# 643/643 [==============================] - 10s 15ms/step - loss: 1.1539 - accuracy: 0.0431 - val_loss: 0.6796 - val_accuracy: 0.0472
# Epoch 9/10
# 643/643 [==============================] - 10s 16ms/step - loss: 1.0334 - accuracy: 0.0446 - val_loss: 0.5136 - val_accuracy: 0.0501
# Epoch 10/10
# 643/643 [==============================] - 10s 16ms/step - loss: 0.9203 - accuracy: 0.0418 - val_loss: 0.3296 - val_accuracy: 0.0488

# %%
model.evaluate(tX,  tY)
# Out:
# 225/225 [==============================] - 1s 3ms/step - loss: 0.4367 - accuracy: 0.0591
# [0.4366742670536041, 0.05911879613995552]

# %%
from keras.applications import MobileNet
from keras.layers import GlobalAveragePooling2D, Dense
from keras.models import Model

base_model=MobileNet(weights='imagenet',include_top=False) 

x=base_model.output
x=GlobalAveragePooling2D()(x)
x=Dense(1024,activation='relu')(x) 
x=Dense(1024,activation='relu')(x) 
x=Dense(512,activation='relu')(x)
preds=Dense(25,activation='softmax')(x) 
model=Model(inputs=base_model.input,outputs=preds)
# Out:
# Using TensorFlow backend.
# /usr/local/lib/python3.6/dist-packages/keras_applications/mobilenet.py:207: UserWarning: `input_shape` is undefined or non-square, or `rows` is not in [128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
#   warnings.warn('`input_shape` is undefined or non-square, '
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.6/mobilenet_1_0_224_tf_no_top.h5
# 17227776/17225924 [==============================] - 2s 0us/step

# %%
print(len(model.layers))
#for layer in model.layers:
#    layer.trainable=False

# or if we want to set the first 20 layers of the network to be non-trainable
for layer in model.layers[:20]:
    layer.trainable=False
for layer in model.layers[20:]:
    layer.trainable=True
# Out:
# 92

# %%
import numpy as np
def transform(dataset):
  newDataset = list()
  for x in dataset:
    x = np.repeat(x, 3, 2)
    newDataset.append(x)
  return np.array(newDataset)

newTrainX = transform(x_train)
newValX = transform(x_val)

print(newTrainX.shape, newValX.shape)
# Out:
# (20591, 28, 28, 3) (6864, 28, 28, 3)

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

model.fit(newTrainX, y_train, validation_data=(newValX, y_val), epochs=10)
# Out:
# Train on 20591 samples, validate on 6864 samples
# Epoch 1/10
# 20591/20591 [==============================] - 30s 1ms/step - loss: 3.2075 - accuracy: 0.0441 - val_loss: 3.2004 - val_accuracy: 0.0450
# Epoch 2/10
# 20591/20591 [==============================] - 27s 1ms/step - loss: 3.1937 - accuracy: 0.0471 - val_loss: 3.1923 - val_accuracy: 0.0450
# Epoch 3/10
# 20591/20591 [==============================] - 26s 1ms/step - loss: 3.1871 - accuracy: 0.0448 - val_loss: 3.1880 - val_accuracy: 0.0450
# Epoch 4/10
# 20591/20591 [==============================] - 27s 1ms/step - loss: 3.1833 - accuracy: 0.0465 - val_loss: 3.1852 - val_accuracy: 0.0450
# Epoch 5/10
# 20591/20591 [==============================] - 26s 1ms/step - loss: 3.1809 - accuracy: 0.0456 - val_loss: 3.1835 - val_accuracy: 0.0450
# Epoch 6/10
# 20591/20591 [==============================] - 26s 1ms/step - loss: 3.1793 - accuracy: 0.0466 - val_loss: 3.1823 - val_accuracy: 0.0450
# Epoch 7/10
# 20591/20591 [==============================] - 26s 1ms/step - loss: 3.1782 - accuracy: 0.0465 - val_loss: 3.1813 - val_accuracy: 0.0450
# Epoch 8/10
# 20591/20591 [==============================] - 26s 1ms/step - loss: 3.1774 - accuracy: 0.0462 - val_loss: 3.1807 - val_accuracy: 0.0450
# Epoch 9/10
# 20591/20591 [==============================] - 26s 1ms/step - loss: 3.1769 - accuracy: 0.0460 - val_loss: 3.1801 - val_accuracy: 0.0450
# Epoch 10/10
# 20591/20591 [==============================] - 25s 1ms/step - loss: 3.1764 - accuracy: 0.0461 - val_loss: 3.1797 - val_accuracy: 0.0450
